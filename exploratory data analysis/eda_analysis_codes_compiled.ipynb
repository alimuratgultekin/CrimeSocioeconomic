# %% [markdown]
# # 📊 Exploratory Data Analysis (EDA)
# This notebook performs EDA on the merged dataset to analyze the relationship between crime rates and socioeconomic factors.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 📂 Load the Merged Dataset

# %%
data = pd.read_csv('Merged_Crime_Socioeconomic_Data.csv')
data.head()
# Out:
#    State_x         City  Population  Violent_Crime  Murder  Rape  Robbery  \
# 0  ALABAMA    Abbeville      2371.0            6.0     0.0   0.0      0.0
# 1  ALABAMA   Adamsville      4158.0           17.0     0.0   1.0      5.0
# 2  ALABAMA      Addison       674.0            3.0     0.0   1.0      0.0
# 3  ALABAMA    Alabaster     34120.0           37.0     1.0   1.0      5.0
# 4  ALABAMA  Albertville     22887.0           68.0     0.0  11.0      3.0
#
#    Aggravated_Assault  Property_Crime  Burglary  Larceny_Theft  \
# 0                 6.0            27.0       6.0           21.0
# 1                11.0           201.0      23.0          158.0
# 2                 2.0            14.0       2.0           10.0
# 3                30.0           551.0      16.0          518.0
# 4                54.0           415.0      40.0          315.0
#
#    Motor_Vehicle_Theft  Arson State_Abbrev State_y  \
# 0                  0.0    0.0           AL      AL
# 1                 20.0    0.0           AL      AL
# 2                  2.0    0.0           AL      AL
# 3                 17.0    2.0           AL      AL
# 4                 60.0    6.0           AL      AL
#
#    Percent_Bachelors_or_Higher  Unemployment_Rate
# 0                    19.645014           2.902941
# 1                    19.645014           2.902941
# 2                    19.645014           2.902941
# 3                    19.645014           2.902941
# 4                    19.645014           2.902941

# %% [markdown]
# ## 📊 Descriptive Statistics

# %%
data.describe()
# Out:
#          Population  Violent_Crime       Murder         Rape       Robbery  \
# count  8.225000e+03    8225.000000  8225.000000  8225.000000   8225.000000
# mean   2.389749e+04     110.115745     1.645957    10.057629     22.137386
# std    1.255860e+05     950.319489    14.038056    55.584945    281.099962
# min    0.000000e+00       0.000000     0.000000     0.000000      0.000000
# 25%    2.547000e+03       3.000000     0.000000     0.000000      0.000000
# 50%    6.803000e+03      11.000000     0.000000     2.000000      1.000000
# 75%    1.895200e+04      40.000000     0.000000     6.000000      4.000000
# max    8.184044e+06   54691.000000   499.000000  2067.000000  16366.000000
#
#        Aggravated_Assault  Property_Crime      Burglary  Larceny_Theft  \
# count         8225.000000     8225.000000   8225.000000    8225.000000
# mean            76.274772      568.790517     71.616413     396.732888
# std            631.923648     3838.686690    433.359451    2695.409953
# min              0.000000        0.000000      0.000000       0.000000
# 25%              2.000000       20.000000      2.000000      14.000000
# 50%              8.000000       75.000000      9.000000      57.000000
# 75%             28.000000      296.000000     34.000000     228.000000
# max          35913.000000   196267.000000  15385.000000  164238.000000
#
#        Motor_Vehicle_Theft        Arson  Percent_Bachelors_or_Higher  \
# count          8225.000000  8213.000000                  8225.000000
# mean            100.441216     3.136491                    26.563972
# std             845.959171    19.764252                     6.938811
# min               0.000000     0.000000                    17.710740
# 25%               1.000000     0.000000                    21.511137
# 50%               6.000000     0.000000                    24.881172
# 75%              24.000000     1.000000                    29.977209
# max           26462.000000   900.000000                    63.563622
#
#        Unemployment_Rate
# count        8225.000000
# mean            3.835363
# std             0.802181
# min             2.120370
# 25%             3.285897
# 50%             3.710112
# 75%             4.601942
# max             5.687097

# %% [markdown]
# ## 🔥 Correlation Heatmap

# %%
plt.figure(figsize=(10,6))
sns.heatmap(data[['Violent_Crime', 'Property_Crime', 'Percent_Bachelors_or_Higher', 'Unemployment_Rate']].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## 📉 Violent Crime vs. % Bachelor's Degree

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x='Percent_Bachelors_or_Higher', y='Violent_Crime', data=data)
plt.title("Violent Crime vs % Bachelor's Degree")
plt.show()

# %% [markdown]
# ## 📉 Property Crime vs. Unemployment Rate

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x='Unemployment_Rate', y='Property_Crime', data=data)
plt.title("Property Crime vs Unemployment Rate")
plt.show()
